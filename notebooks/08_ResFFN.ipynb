# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.home() / 'Desktop' / 'Master Thesis' / 'NES_Spins'
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

import numpy as np
from nes_lattice.lattice import toric_code_move_masks, toric_code_plaquette_values
from nes_lattice.train import TrainConfig, train, save_history
from nes_lattice.plots import plot_history, plot_diagnostics, print_final

# %%
cfg = TrainConfig(
    shape=(4, 4),
    hamiltonian="toric_code",
    k=5,
    model="toric_rbm",
    rbm_hidden=256,
    init_scale=0.02,

    steps=2000,
    lr=1e-4,
    grad_clip=1.0,
    n_chains=512,
    n_samples=64,
    sweep_steps=128,
    burn_in=1024,

    toric_loop_prob=0.0,
    toric_single_flip_prob=0.0,
    toric_cover_sectors=True,
)

params, history = train(cfg)
save_path = PROJECT_ROOT / 'results' / 'sampled_nes_toric_4x4_k4_rbm_toricmoves.json'
save_history(history, save_path, cfg)
print_final(save_path)
fig, ax = plot_history(save_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 22
#      18     toric_single_flip_prob=0.0,
#      19     toric_cover_sectors=True,
#      20 )
#      21
# ---> 22 params, history = train(cfg)
#      23 save_path = PROJECT_ROOT / 'results' / 'sampled_nes_toric_4x4_k4_rbm_toricmoves.json'
#      24 save_history(history, save_path, cfg)
#      25 print_final(save_path)
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/train.py:146, in train(cfg)
#     144 params = init_model(key_params, mspec)
#     145 opt = init_adam(params)
# --> 146 bundles, _ = initialize_valid_bundles(
#     147     apply_fun=apply_fun,
#     148     params=params,
#     149     key=key_init,
#     150     n_chains=cfg.n_chains,
#     151     k=cfg.k,
#     152     shape=cfg.shape,
#     153     move_type=hspec.move_type,
#     154     n_sites=hspec.N,
#     155     toric_cover_sectors=cfg.toric_cover_sectors,
#     156 )
#     158 sample_fn = make_bundle_sampler(
#     159     apply_fun=apply_fun,
#     160     shape=cfg.shape,
#    (...)    169     toric_single_flip_prob=cfg.toric_single_flip_prob,
#     170 )
#     172 @jax.jit
#     173 def train_step(params, opt, samples):
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/sampler.py:174, in initialize_valid_bundles(apply_fun, params, key, n_chains, k, shape, move_type, n_sites, max_retries, toric_cover_sectors)
#     163 bundles = init_bundles(
#     164     key_init,
#     165     n_chains,
#    (...)    170     toric_cover_sectors=toric_cover_sectors,
#     171 )
#     173 for _ in range(max_retries):
# --> 174     invalid = ~jnp.isfinite(batch_logabsdet(apply_fun, params, bundles))
#     175     if not bool(jnp.any(invalid)):
#     176         return bundles, key
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/nes.py:23, in batch_logabsdet(apply_fun, params, bundles)
#      22 def batch_logabsdet(apply_fun, params, bundles: jnp.ndarray):
# ---> 23     return jax.vmap(lambda b: logabsdet_bundle(apply_fun, params, b))(bundles)
#
#     [... skipping hidden 1 frame]
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/api.py:1186, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1183 try:
#    1184   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1185                                 explicit_mesh_axis)
# -> 1186   out_flat, inferred_out_axes = batching.batch(
#    1187       flat_fun, axis_data, in_axes_flat,
#    1188       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1189       sum_match=sum_match
#    1190   ).call_wrapped(*args_flat)
#    1191 except batching.SpecMatchError as e:
#    1192   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:340, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     338 tag = TraceTag()
#     339 with source_info_util.transform_name_stack('vmap'):
# --> 340   outs, out_dim_srcs, trace = f(tag, in_dims, *in_vals)
#     341 with core.ensure_no_leaks(trace): del trace
#     342 return outs, out_dim_srcs
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:359, in _batch_inner(f, axis_data, out_dim_dests, sum_match, tag, in_dims, *in_vals)
#     353 # TODO(yashkatariya): Instead of `add_explicit_mesh_axis_names`, we should
#     354 # create a new mesh by removing the axis_data.explicit_mesh_axis from it.
#     355 with (core.set_current_trace(trace),
#     356       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     357       core.add_spmd_axis_names(axis_data.spmd_name),
#     358       core.add_explicit_mesh_axis_names(axis_data.explicit_mesh_axis)):
# --> 359   outs = f(*in_tracers)
#     360   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     361   out_vals, out_dim_srcs = unzip2(
#     362       map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis, sum_match),
#     363           range(len(outs)), outs, out_dim_dests))  # pyrefly: ignore[bad-argument-type]  # pyrefly#2385
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:122, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     118 @lu.transformation_with_aux2
#     119 def flatten_fun_for_vmap(f: Callable,
#     120                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     121   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 122   ans = f(*py_args, **py_kwargs)
#     123   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     124   store.store(out_tree)
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/nes.py:23, in batch_logabsdet.<locals>.<lambda>(b)
#      22 def batch_logabsdet(apply_fun, params, bundles: jnp.ndarray):
# ---> 23     return jax.vmap(lambda b: logabsdet_bundle(apply_fun, params, b))(bundles)
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/nes.py:19, in logabsdet_bundle(apply_fun, params, bundle)
#      18 def logabsdet_bundle(apply_fun, params, bundle: jnp.ndarray):
# ---> 19     return signed_logdet_bundle(apply_fun, params, bundle)[1]
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/nes.py:15, in signed_logdet_bundle(apply_fun, params, bundle)
#      14 def signed_logdet_bundle(apply_fun, params, bundle: jnp.ndarray):
# ---> 15     return jnp.linalg.slogdet(amplitude_matrix(apply_fun, params, bundle))
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/nes.py:11, in amplitude_matrix(apply_fun, params, bundle)
#       9 def amplitude_matrix(apply_fun, params, bundle: jnp.ndarray) -> jnp.ndarray:
#      10     """Physical NES matrix A[i, j] = psi_i(sigma_j), with no determinant jitter."""
# ---> 11     return apply_fun(params, bundle).T
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/train.py:104, in make_apply_fun.<locals>.<lambda>(params, spins)
#     103 def make_apply_fun(mspec: ModelSpec):
# --> 104     return lambda params, spins: apply_model(params, spins, mspec)
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/models.py:117, in apply_model(params, spins, spec)
#     115     return apply_rbm(params, spins)
#     116 if spec.model == "toric_rbm":
# --> 117     return apply_toric_rbm(params, spins, spec.shape)
#     118 if spec.model == "cnn":
#     119     return apply_cnn(params, spins, spec.shape)
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/models.py:357, in apply_toric_rbm(params, spins, shape)
#     354 flat = s.reshape((-1, s.shape[-1]))
#     356 rbm_vals = apply_rbm(params, flat)
# --> 357 projectors = _toric_projectors(flat, shape, rbm_vals.shape[-1], dtype)
#     358 out = rbm_vals * projectors
#     359 return out.reshape((*orig_batch, out.shape[-1]))
#
# File ~/Desktop/Master Thesis/NES_Spins/src/nes_lattice/models.py:337, in _toric_projectors(spins, shape, k, dtype)
#     334 b_p = jnp.prod(spins[:, plaquettes], axis=-1)
#     335 flux_free = jnp.prod(0.5 * (b_p + 1.0), axis=-1).astype(dtype)
# --> 337 wx = jnp.prod(spins[:, horizontal_loop], axis=-1)
#     338 wy = jnp.prod(spins[:, vertical_loop], axis=-1)
#     340 labels = jnp.arange(k)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/numpy/reductions.py:397, in prod(a, axis, dtype, out, keepdims, initial, where, promote_integers)
#     326 @export
#     327 def prod(a: ArrayLike, axis: Axis = None, dtype: DTypeLike | None = None,
#     328          out: None = None, keepdims: bool = False,
#     329          initial: ArrayLike | None = None, where: ArrayLike | None = None,
#     330          promote_integers: bool = True) -> Array:
#     331   r"""Return product of the array elements over a given axis.
#     332
#     333   JAX implementation of :func:`numpy.prod`.
#    (...)    395            [1]], dtype=int32)
#     396   """
# --> 397   return _reduce_prod(a, axis=_ensure_optional_axes(axis), dtype=dtype,
#     398                       out=out, keepdims=keepdims, initial=initial, where=where,
#     399                       promote_integers=promote_integers)
#
#     [... skipping hidden 1 frame]
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/pjit.py:259, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     256                      "`jit`, but 'no_tracing' is set")
#     257 p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     258 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 259  executable, pgle_profiler, const_args) = _run_python_pjit(
#     260      p, args_flat, fun, args, kwargs)
#     262 maybe_fastpath_data = _get_fastpath_data(
#     263     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     264     pgle_profiler, const_args)
#     266 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/pjit.py:142, in _run_python_pjit(p, args_flat, fun, args, kwargs)
#     139   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     140       *args_flat, **p.params)
#     141 else:
# --> 142   out_flat = jit_p.bind(*args_flat, **p.params)
#     143   compiled = None
#     144   profiler = None
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/core.py:705, in Primitive.bind(self, *args, **params)
#     703 trace_ctx.set_trace(eval_trace)
#     704 try:
# --> 705   return self.bind_with_trace(prev_trace, args, avals, params)
#     706 finally:
#     707   trace_ctx.set_trace(prev_trace)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/core.py:713, in Primitive.bind_with_trace(self, trace, args, avals, params)
#     711   with set_current_trace(trace):
#     712     return self.to_lojax(*args, **params)  # pyrefly: ignore[not-callable]
# --> 713 return trace.process_primitive(self, args, params)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:263, in BatchTrace.process_primitive(self, p, tracers, params)
#     258 if p in fancy_primitive_batchers:
#     259   # TODO(yashkatariya): Remove remove_explicit_mesh_axis_names when vmap
#     260   # mesh ctx is correctly set.
#     261   with (core.set_current_trace(self.parent_trace),
#     262         core.remove_explicit_mesh_axis_names(self.axis_data.explicit_mesh_axis)):
# --> 263     val_out, dim_out = fancy_primitive_batchers[p](
#     264         self.axis_data, vals_in, dims_in, **params)
#     265     src = source_info_util.current()
#     266     if p.multiple_results:
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/pjit.py:1473, in _pjit_batcher(axis_data, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs)
#    1468 if not (all(l is None for l in in_layouts) and
#    1469         all(l is None for l in out_layouts)):
#    1470   raise NotImplementedError(
#    1471       'Concrete layouts are not supported for vmap(jit).')
# -> 1473 vals_out = jit_p.bind(
#    1474   *vals_in,
#    1475   jaxpr=new_jaxpr,
#    1476   in_shardings=in_shardings,
#    1477   out_shardings=out_shardings,
#    1478   in_layouts=in_layouts,
#    1479   out_layouts=out_layouts,
#    1480   donated_invars=donated_invars,
#    1481   ctx_mesh=ctx_mesh,
#    1482   name=name,
#    1483   keep_unused=keep_unused,
#    1484   inline=inline,
#    1485   compiler_options_kvs=compiler_options_kvs)
#    1487 return vals_out, axes_out
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/core.py:705, in Primitive.bind(self, *args, **params)
#     703 trace_ctx.set_trace(eval_trace)
#     704 try:
# --> 705   return self.bind_with_trace(prev_trace, args, avals, params)
#     706 finally:
#     707   trace_ctx.set_trace(prev_trace)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/core.py:713, in Primitive.bind_with_trace(self, trace, args, avals, params)
#     711   with set_current_trace(trace):
#     712     return self.to_lojax(*args, **params)  # pyrefly: ignore[not-callable]
# --> 713 return trace.process_primitive(self, args, params)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/core.py:1294, in EvalTrace.process_primitive(self, primitive, args, params)
#    1292 args = map(full_lower, args)
#    1293 check_eval_args(args)
# -> 1294 return primitive.impl(*args, **params)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/pjit.py:1239, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1231 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1232 cache_key = pxla.JitGlobalCppCacheKeys(
#    1233     donate_argnums=donated_argnums, donate_argnames=None,
#    1234     device=None, backend=None,
#    (...)   1237     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1238     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1239 return _jax.pjit(
#    1240     name, f, call_impl_cache_miss, [], [], cache_key,
#    1241     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1242     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/pjit.py:1215, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1211 def call_impl_cache_miss(*args_, **kwargs_):
#    1212   # args_ do not include the const args
#    1213   # See https://docs.jax.dev/en/latest/internals/constants.html.
#    1214   # TODO(necula): remove num_const_args when fixing the C++ path
# -> 1215   out_flat, compiled, pgle_profiler, const_args = _pjit_call_impl_python(
#    1216       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1217       out_shardings=out_shardings, in_layouts=in_layouts,
#    1218       out_layouts=out_layouts, donated_invars=donated_invars,
#    1219       ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1220       inline=inline, compiler_options_kvs=compiler_options_kvs)
#    1221   fastpath_data = _get_fastpath_data(
#    1222       compiled, tree_structure(out_flat), args, out_flat,
#    1223       jaxpr.effects, jaxpr.consts, pgle_profiler,
#    1224       const_args)
#    1225   return out_flat, fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/pjit.py:1175, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1164 arg_types = map(convert_to_metaty, args)
#    1165 computation = _resolve_and_lower(
#    1166     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1167     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1173     compiler_options_kvs=compiler_options_kvs,
#    1174 )
# -> 1175 compiled = computation.compile()
#    1176 sharded_const_args = compiled.shard_const_args(computation.const_args)
#    1178 if config.distributed_debug.value:
#    1179   # Defensively only perform fingerprint logic if debug logging is enabled
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1239, in MeshComputation.compile(self, compiler_options, device_assignment)
#    1236 if use_cache and self._executable is not None:
#    1237   return self._executable
# -> 1239 executable = UnloadedMeshExecutable.from_hlo(
#    1240     self._name, self._hlo, **self.compile_args,
#    1241     compiler_options_kvs=compiler_options_kvs,
#    1242     device_list=compilation_device_list)
#    1243 if use_cache:
#    1244   self._executable = executable
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1733, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    1729 allow_prop_to_inputs, allow_prop_to_outputs = get_prop_to_input_output(
#    1730     in_shardings, out_shardings, len(ordered_effects))
#    1732 util.test_event("pxla_cached_compilation")
# -> 1733 xla_executable = _cached_compilation(
#    1734     hlo, name, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs,
#    1735     tuple(host_callbacks), backend, device_list, compiler_options_kvs,
#    1736     pgle_profiler)
#    1738 in_shardings = _maybe_get_and_check_in_shardings(
#    1739     xla_executable, in_shardings, device_list, global_in_avals,
#    1740     len(ordered_effects))
#    1741 out_shardings = _maybe_get_and_check_out_shardings(
#    1742     xla_executable, out_shardings, device_list, global_out_avals,
#    1743     len(ordered_effects))
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1516, in _cached_compilation(computation, name, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, compiler_options_kvs, pgle_profiler)
#    1509 compile_options = create_compile_options(
#    1510     computation, tuple_args, allow_prop_to_inputs, allow_prop_to_outputs,
#    1511     backend, dev, compiler_options)
#    1513 with dispatch.log_elapsed_time(
#    1514     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    1515     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 1516   xla_executable = compiler.compile_or_get_cached(
#    1517       backend, computation, dev, compile_options, host_callbacks,
#    1518       da, pgle_profiler)
#    1519 return xla_executable
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/compiler.py:469, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     467 else:
#     468   log_persistent_cache_miss(module_name, cache_key)
# --> 469   return _compile_and_write_cache(
#     470       backend,
#     471       computation,
#     472       executable_devices,
#     473       compile_options,
#     474       host_callbacks,
#     475       module_name,
#     476       cache_key,
#     477   )
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/compiler.py:737, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     727 def _compile_and_write_cache(
#     728     backend: xc.Client,
#     729     computation: ir.Module,
#    (...)    734     cache_key: str,
#     735 ) -> xc.LoadedExecutable:
#     736   start_time = time.monotonic()
# --> 737   executable = backend_compile_and_load(
#     738       backend, computation, executable_devices, compile_options, host_callbacks
#     739   )
#     740   compile_time = time.monotonic() - start_time
#     741   _cache_write(
#     742       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     743   )
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/profiler.py:420, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     417 @wraps(func)
#     418 def wrapper(*args, **kwargs):
#     419   with TraceAnnotation(name, **decorator_kwargs):
# --> 420     return func(*args, **kwargs)
#
# File ~/venv/nqs311/lib/python3.11/site-packages/jax/_src/compiler.py:353, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     344       return backend.compile_and_load(
#     345           module,
#     346           executable_devices=executable_devices,
#     347           compile_options=options,
#     348           host_callbacks=host_callbacks,
#     349       )
#     350     # Some backends don't have `host_callbacks` option yet
#     351     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     352     # to take in `host_callbacks`
# --> 353     return backend.compile_and_load(
#     354         module,
#     355         executable_devices=executable_devices,
#     356         compile_options=options,
#     357     )
#     358 except _jax.JaxRuntimeError as e:
#     359   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
cfg = TrainConfig(
    shape=(4,4),
    hamiltonian="toric_code",
    k=4,
    model="resffn",
    hidden=(512,512,512),
    init_scale=0.005,

    Je=1.0,
    Jm=1.0,

    steps=20000,
    lr=2e-5,
    grad_clip=0.5,

    n_chains=1024,
    n_samples=64,
    sweep_steps=128,
    burn_in=1024,

    toric_loop_prob=0.10,
    toric_single_flip_prob=0.0,
    toric_cover_sectors=True,

    print_every=500,
    eval_chains=1024,
    eval_samples=128,
    reference="auto",
    seed=4,
)
params, history = train(cfg)
save_path = PROJECT_ROOT / 'results' / 'sampled_nes_toric_4x4_k4_rbm_toricmoves.json'
save_history(history, save_path, cfg)
print_final(save_path)
fig, ax = plot_history(save_path)

# %%
cfg = TrainConfig(
    shape=(4, 4),
    hamiltonian="toric_code",
    k=5,
    model="toric_rbm",
    rbm_hidden=256,
    init_scale=0.02,

    steps=1000,
    lr=1e-4,
    grad_clip=1.0,
    n_chains=512,
    n_samples=16,
    sweep_steps=128,
    burn_in=32,

    toric_loop_prob=0.15,
    toric_single_flip_prob=0.0,
    toric_cover_sectors=True,
    reference = 'ed',
    seed=4
)

params, history = train(cfg)
save_path = PROJECT_ROOT / 'results' / 'sampled_nes_toric_4x4_k5_rbm_toricmoves.json'
save_history(history, save_path, cfg)
print_final(save_path)
fig, ax = plot_history(save_path)
# Out:
# {'step': 0, 'loss_sum': -155.79827288316943, 'train_energy_estimator': nan, 'energies': [-32.005328230560515, -31.95028365086741, -31.92731405041882, -31.917768487183178, -27.997578464139522], 'reference': None, 'reference_source': 'own ED skipped because N=32 > max_sites=14', 'abs_errors': None, 'trace_error': None, 'condition_number_S': 127.86602119686961, 'sampler_accept_rate': nan, 'sampler_star_accept_rate': nan, 'sampler_loop_accept_rate': nan, 'sampler_single_flip_accept_rate': nan, 'sampler_star_move_fraction': nan, 'sampler_loop_move_fraction': nan, 'sampler_single_flip_move_fraction': nan, 'invalid_bundle_fraction': nan, 'grad_norm': nan, 'eval': {'accept_rate': 0.9092254638671875, 'burn_accept_rate': 0.908862292766571, 'burn_loop_accept_rate': 0.7442314028739929, 'burn_loop_move_fraction': 0.15024414658546448, 'burn_single_flip_accept_rate': 0.0, 'burn_single_flip_move_fraction': 0.0, 'burn_star_accept_rate': 0.9379704594612122, 'burn_star_move_fraction': 0.8497558832168579, 'loop_accept_rate': 0.7481131553649902, 'loop_move_fraction': 0.14859771728515625, 'single_flip_accept_rate': 0.0, 'single_flip_move_fraction': 0.0, 'star_accept_rate': 0.9373448491096497, 'star_move_fraction': 0.8514022827148438, 'S_min_eig': 0.0031165026637171717, 'S_max_eig': 0.39849479565896045, 'S_rank': 5, 'S_floor': 1e-06, 'S_num_clipped': 0, 'S_eigenvalues': [0.0031165026637171717, 0.189453125, 0.197021484375, 0.2119140625, 0.39849479565896045], 'method': 'sampled_span_q'}}
