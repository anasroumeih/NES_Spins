# %% [markdown]
# # 03 — Plot saved results
#
# Load the JSON from notebook 02 and plot energies/diagnostics.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.home() / "Desktop" / "Master Thesis" / "nes_lattice_project"
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from nes_lattice.plots import plot_history, plot_diagnostics, print_final

# %%
result_path = PROJECT_ROOT / "results" / "sampled_nes_1d_tfim_L10_k2_ffn.json"
print_final(result_path)

# %%
fig, ax = plot_history(result_path)
fig

# %%
(fig1, ax1), (fig2, ax2) = plot_diagnostics(result_path)
fig1

# %%
fig2

# %%
result_path = PROJECT_ROOT / "results" / "sampled_nes_2d_tfim_4x4_k2_cnn.json"
print_final(result_path)
# Out:
# File:               /home/a/Anas.Roumeih/Desktop/Master Thesis/nes_lattice_project/results/sampled_nes_2d_tfim_4x4_k2_cnn.json
# Config:             {'shape': [4, 4], 'hamiltonian': 'tfim', 'k': 2, 'J': 1.0, 'g': 1.0, 'Je': None, 'Jm': None, 'pbc': True, 'magnetization': None, 'model': 'cnn', 'hidden': [64, 64], 'rbm_hidden': 32, 'channels': [16, 16], 'kernel_size': 3, 'init_scale': 0.05, 'dtype': 'float32', 'steps': 8000, 'lr': 0.002, 'n_chains': 64, 'n_samples': 8, 'sweep_steps': 16, 'burn_in': 160, 'det_jitter': 1e-08, 'grad_clip': 10.0, 'print_every': 100, 'eval_exact_if_sites_leq': 16, 'eval_samples': 32, 'eval_chains': 128, 'reference': 'auto', 'own_ed_max_sites': 14, 'netket_max_states': 2000000, 'jitter': 1e-08, 'seed': 1}
# Final NES energies: [-33.92841438424119, -33.34255837271996]
# Reference:          [-34.01059755084618, -34.010596999468305]
# Reference source:   netket_lanczos_ed
# Abs errors:         [0.0821831666049917, 0.6680386267483485]
# ...

# %%
fig, ax = plot_history(result_path)

# %%
result_path = PROJECT_ROOT / "results" / "sampled_nes_2d_tfim_4x4_k2_rbm.json"
print_final(result_path)
# Out:
# File:               /home/a/Anas.Roumeih/Desktop/Master Thesis/nes_lattice_project/results/sampled_nes_2d_tfim_4x4_k2_rbm.json
# Config:             {'shape': [4, 4], 'hamiltonian': 'tfim', 'k': 4, 'J': 1.0, 'g': 1.0, 'pbc': True, 'magnetization': None, 'model': 'rbm', 'hidden': [64, 64], 'rbm_hidden': 64, 'channels': [16, 16], 'kernel_size': 3, 'init_scale': 0.05, 'steps': 2500, 'lr': 0.001, 'n_chains': 64, 'n_samples': 8, 'sweep_steps': 16, 'burn_in': 160, 'det_jitter': 1e-08, 'grad_clip': 10.0, 'print_every': 100, 'eval_exact_if_sites_leq': 16, 'eval_samples': 32, 'eval_chains': 128, 'reference': 'auto', 'own_ed_max_sites': 14, 'netket_max_states': 2000000, 'jitter': 1e-08, 'seed': 2}
# Final NES energies: [-33.99406499216678, -33.991485724420414, -26.71131207656529, -26.693289210942954]
# Reference:          [-34.01059755084626, -34.010596999468234, -26.725061975707394, -26.724197437001802]
# Reference source:   netket_lanczos_ed
# ...

# %%
fig, ax = plot_history(result_path)

# %%
result_path = PROJECT_ROOT / "results" / "sampled_nes_2d_heisenberg_4x4_k2_rbm.json"
print_final(result_path)
# Out:
# File:               /home/a/Anas.Roumeih/Desktop/Master Thesis/nes_lattice_project/results/sampled_nes_2d_heisenberg_4x4_k2_rbm.json
# Config:             {'shape': [4, 4], 'hamiltonian': 'heisenberg', 'k': 4, 'J': 1.0, 'g': 1.0, 'pbc': True, 'magnetization': None, 'model': 'rbm', 'hidden': [64, 64], 'rbm_hidden': 128, 'channels': [16, 16], 'kernel_size': 3, 'init_scale': 0.05, 'steps': 1500, 'lr': 0.005, 'n_chains': 64, 'n_samples': 16, 'sweep_steps': 16, 'burn_in': 160, 'det_jitter': 1e-08, 'grad_clip': 10.0, 'print_every': 100, 'eval_exact_if_sites_leq': 16, 'eval_samples': 32, 'eval_chains': 128, 'reference': 'auto', 'own_ed_max_sites': 14, 'netket_max_states': 2000000, 'jitter': 1e-08, 'seed': 2}
# Final NES energies: [-8.914271351033104, -3.663363916472574, -2.999050584831247, -2.987202005467945]
# Reference:          [-44.913932833715435, -42.59953949065363, -38.07075193574913, -35.54576963122616]
# Reference source:   netket_lanczos_ed
# ...

# %%
fig, ax = plot_history(result_path)

# %% [markdown]
# # 5x5 TFIM

# %%
result_path = PROJECT_ROOT / "results" / "sampled_nes_2d_tfim_5x5_k2_rbm.json"
print_final(result_path)
# Out:
# File:               /home/a/Anas.Roumeih/Desktop/Master Thesis/nes_lattice_project/results/sampled_nes_2d_tfim_5x5_k2_rbm.json
# Config:             {'shape': [5, 5], 'hamiltonian': 'tfim', 'k': 4, 'J': 1.0, 'g': 1.0, 'pbc': True, 'magnetization': None, 'model': 'rbm', 'hidden': [64, 64], 'rbm_hidden': 64, 'channels': [16, 16], 'kernel_size': 3, 'init_scale': 0.05, 'steps': 2500, 'lr': 0.001, 'n_chains': 64, 'n_samples': 8, 'sweep_steps': 25, 'burn_in': 250, 'det_jitter': 1e-08, 'grad_clip': 10.0, 'print_every': 100, 'eval_exact_if_sites_leq': 16, 'eval_samples': 32, 'eval_chains': 128, 'reference': 'auto', 'own_ed_max_sites': 14, 'netket_max_states': 2000000, 'jitter': 1e-08, 'seed': 2}
# Final NES energies: [-53.11817329765947, -53.11349257736669, -45.73628599430172, -45.73488188965566]
# Reference:          None
# Reference source:   own ED skipped because N=25 > max_sites=14
# Abs errors:         None
# Trace error:        None
# cond(S):            26.91275341840953
# ...

# %%
fig, ax = plot_history(result_path)
