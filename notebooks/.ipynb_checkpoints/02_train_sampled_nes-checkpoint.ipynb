# %% [markdown]
# # 02 — Train sampled NES
#
# Run one experiment, save it as JSON, then plot/read it in notebook 03.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.home() / "nes_lattice_project"
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from nes_lattice.train import TrainConfig, train, save_history

# %%
# Example A: 1D TFIM, k=2, FFN. Good first sanity check.
cfg = TrainConfig(
    shape=(10,),
    hamiltonian="tfim",
    k=2,
    g=1.0,
    model="ffn",
    hidden=(128, 128),
    steps=500,
    lr=2e-3,
    n_chains=64,
    n_samples=8,
    print_every=100,
    seed=0,
)

params, history = train(cfg)

results_dir = PROJECT_ROOT / "results"
results_dir.mkdir(parents=True, exist_ok=True)
save_path = results_dir / "sampled_nes_1d_tfim_L10_k2_ffn.json"
save_history(history, save_path, cfg)
print("saved to:", save_path)

# %%
# Example B: 2D TFIM, CNN. Uncomment when the first run works.
# cfg = TrainConfig(
#     shape=(4,4),
#     hamiltonian="tfim",
#     k=2,
#     g=1.0,
#     model="cnn",
#     channels=(16, 16),
#     steps=1000,
#     lr=1e-3,
#     n_chains=64,
#     n_samples=8,
#     print_every=100,
#     seed=1,
# )
# params, history = train(cfg)
# save_path = PROJECT_ROOT / "results" / "sampled_nes_2d_tfim_4x4_k2_cnn.json"
# save_history(history, save_path, cfg)
# print("saved to:", save_path)

# %%
# Example C: 2D Heisenberg, RBM. Uncomment after trying TFIM.
# cfg = TrainConfig(
#     shape=(4,4),
#     hamiltonian="heisenberg",
#     k=2,
#     J=1.0,
#     model="rbm",
#     rbm_hidden=64,
#     steps=1500,
#     lr=1e-3,
#     n_chains=64,
#     n_samples=8,
#     print_every=100,
#     seed=2,
# )
# params, history = train(cfg)
# save_path = PROJECT_ROOT / "results" / "sampled_nes_2d_heisenberg_4x4_k2_rbm.json"
# save_history(history, save_path, cfg)
# print("saved to:", save_path)
